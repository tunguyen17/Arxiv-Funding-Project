# %%
from bs4 import BeautifulSoup

import time

import urllib
import urllib.request
from urllib.error import HTTPError

import io
import re
from math import floor
import random
import pandas as pd
import numpy as np

# %%
# Finding all the categories

url = "http://export.arxiv.org/oai2?verb=ListSets"
u = urllib.request.urlopen(url, data = None)
f = io.TextIOWrapper(u,encoding='utf-8')
text = f.read()
soup = BeautifulSoup(text, 'xml')
all_cat = [sp.text for sp in soup.findAll("setSpec")]

f = open("all_cat_v01.txt", "w")
f.write(",".join(all_cat))
f.close()

# %%
all_cat
# Out:
# ['cs',
#  'econ',
#  'eess',
#  'math',
#  'physics',
#  'physics:astro-ph',
#  'physics:cond-mat',
#  'physics:gr-qc',
#  'physics:hep-ex',
#  'physics:hep-lat',
#  'physics:hep-ph',
#  'physics:hep-th',
#  'physics:math-ph',
#  'physics:nlin',
#  'physics:nucl-ex',
#  'physics:nucl-th',
#  'physics:physics',
#  'physics:quant-ph',
#  'q-bio',
#  'q-fin',
#  'stat']

# %%
def scrape(cat):
    
    # Initialization
    df = pd.DataFrame(columns=("doi", "date", "title", "authors", "category"))
    base_url = "http://export.arxiv.org/oai2?verb=ListRecords&"
    url = base_url + "set={}&metadataPrefix=arXiv".format(cat)
    
    # while loop in order to loop through all the resutls
    while True:
        # print url to keep track of stuff
        print(url)
        # accessing the url
        try:
            u = urllib.request.urlopen(url, data = None)
        except HTTPError as e:
            # Incase of some error that require us to wait
            if e.code == 503:
                to = int(e.hdrs.get("retry-after", 30))
                print("Got 503. Retrying after {0:d} seconds.".format(to))
                time.sleep(to)
                continue # Skip this loop, continue to the next one
            else:
                raise

        # reading the file
        f = io.TextIOWrapper(u,encoding='utf-8')
        text = f.read()
        soup = BeautifulSoup(text, 'xml')

        # collecting the data
        for record in soup.findAll("record"):
            try:
                doi = record.find("identifier").text
            except:
                doi = np.nan
            
            try:
                date = record.find("created").text
            except:
                date = np.nan
            
            try:
                title = record.find("title").text
            except:
                title = np.nan
            
            try:
                authors = ";".join([author.get_text(" ") for author in record.findAll("author")])
            except:
                authros = np.nan
            
            try:
                category = record.find("setSpec").text
            except:
                category = np.nan
                
            df = df.append({"doi":doi, "date":date, "title":title, "authors":authors, "category":category}, ignore_index=True)
                

        # Seeing if there is still data

        token = soup.find("resumptionToken")
        if token is None or token.text is None:
            break
        else:
            url = base_url + "resumptionToken=%s"%(token.text)
        
    return(df)

# %%
cat = "physics"

# Initialization
df = pd.DataFrame(columns=("doi", "date", "title", "authors", "category"))
base_url = "http://export.arxiv.org/oai2?verb=ListRecords&"
url = base_url + "set={}&metadataPrefix=arXiv".format(cat)

# while loop in order to loop through all the resutls
while True:
    # print url to keep track of stuff
    print(url)
    # accessing the url
    try:
        u = urllib.request.urlopen(url, data = None)
    except HTTPError as e:
        # Incase of some error that require us to wait
        if e.code == 503:
            to = int(e.hdrs.get("retry-after", 30))
            print("Got 503. Retrying after {0:d} seconds.".format(to))
            time.sleep(to)
            continue # Skip this loop, continue to the next one
        else:
            raise

    # reading the file
    f = io.TextIOWrapper(u,encoding='utf-8')
    text = f.read()
    soup = BeautifulSoup(text, 'xml')

    # collecting the data
    for record in soup.findAll("record"):
        try:
            doi = record.find("identifier").text
        except:
            doi = np.nan

        try:
            date = record.find("created").text
        except:
            date = np.nan

        try:
            title = record.find("title").text
        except:
            title = np.nan

        try:
            authors = ";".join([author.get_text(" ") for author in record.findAll("author")])
        except:
            authros = np.nan

        try:
            category = record.find("setSpec").text
        except:
            category = np.nan

        df = df.append({"doi":doi, "date":date, "title":title, "authors":authors, "category":category}, ignore_index=True)


    # Seeing if there is still data

    token = soup.find("resumptionToken")
    if token is None or token.text is None:
        break
    else:
        url = base_url + "resumptionToken=%s"%(token.text)
# Out:
# http://export.arxiv.org/oai2?verb=ListRecords&set=physics&metadataPrefix=arXiv
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|1001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|2001
# Got 503. Retrying after 10 seconds.
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|2001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|3001
# Got 503. Retrying after 10 seconds.
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|3001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|4001
# Got 503. Retrying after 10 seconds.
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|4001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|5001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|6001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|7001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|8001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|9001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|10001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|11001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|12001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|13001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|14001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|15001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|16001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|17001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|18001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|19001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|20001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|21001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|22001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|23001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|24001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|25001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|26001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|27001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|28001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|29001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|30001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|31001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|32001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|33001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|34001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|35001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|36001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|37001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|38001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|39001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|40001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|41001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|42001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|43001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|44001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|45001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|46001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|47001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|48001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|49001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|50001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|51001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|52001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|53001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|54001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|55001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|56001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|57001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|58001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|59001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|60001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|61001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|62001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|63001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|64001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|65001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|66001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|67001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|68001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|69001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|70001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|71001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|72001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|73001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|74001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|75001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|76001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|77001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|78001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|79001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|80001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|81001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|82001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|83001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|84001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|85001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|86001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|87001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|88001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|89001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|90001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|91001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|92001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|93001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|94001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|95001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|96001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|97001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|98001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|99001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|100001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|101001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|102001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|103001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|104001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|105001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|106001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|107001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|108001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|109001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|110001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|111001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|112001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|113001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|114001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|115001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|116001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|117001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|118001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|119001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|120001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|121001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|122001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|123001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|124001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|125001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|126001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|127001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|128001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|129001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|130001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|131001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|132001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|133001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|134001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|135001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|136001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|137001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|138001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|139001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|140001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|141001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|142001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|143001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|144001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|145001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|146001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|147001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|148001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|149001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|150001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|151001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|152001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|153001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|154001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|155001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|156001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|157001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|158001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|159001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|160001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|161001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|162001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|163001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|164001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|165001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|166001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|167001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|168001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|169001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|170001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|171001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|172001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|173001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|174001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|175001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|176001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|177001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|178001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|179001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|180001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|181001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|182001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|183001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|184001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|185001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|186001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|187001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|188001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|189001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|190001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|191001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|192001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|193001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|194001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|195001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|196001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|197001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|198001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|199001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|200001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|201001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|202001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|203001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|204001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|205001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|206001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|207001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|208001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|209001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|210001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|211001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|212001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|213001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|214001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|215001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|216001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|217001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|218001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|219001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|220001
# Got 503. Retrying after 600 seconds.
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|220001
# Got 503. Retrying after 600 seconds.
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|220001
# Got 503. Retrying after 600 seconds.
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|220001
# Got 503. Retrying after 600 seconds.
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|220001
# Got 503. Retrying after 600 seconds.
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|220001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|221001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|222001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|223001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497|224001
# http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=2212497